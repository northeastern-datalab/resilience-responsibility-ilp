# %%
# This Notebook contains all the experimental figures used in the submitted paper.

# Import required methods
import sys
sys.path.append('./../../../resilience_code/')

import plot.synthetic_expt_plotter

# %% [markdown]
# ## TPCH Responsibility Experiments

# %%
PLOT_OUTPUT_FILE = None # To show output in notebook
hide_bottom_plots = True

# %%
EXPT_DATA_FILE = './../../../resilience_code/data/tpch_expt/expt-resp-case-{}.csv'
PLOT_OUTPUT_FILE = './../../../resilience_code/data/plots/sigmod_figures/expt-tpch-resp-5Chain.pdf'
expt_type = 'Responsibility'
BUCKET_SIZE_DENOMINATOR = 2
DATA_ALPHA = 0.1
g11_ymax = 2
g00_ymax = 1e4
g01_ymax = 2* 1e4
g00_ymin = 1e-1
xmax = 1e7*1.5
xmin = 1e2
g00_arrow_point = 13
plot.synthetic_expt_plotter.plot_resilience_expt(1, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, BUCKET_SIZE_DENOMINATOR = BUCKET_SIZE_DENOMINATOR, expt_type= expt_type, DATA_ALPHA = DATA_ALPHA, xmax=xmax, xmin=xmin, g00_ymax = g00_ymax, g01_ymax = g01_ymax, g00_ymin = g00_ymin, g00_arrow_point = g00_arrow_point)
# Out:
# Saving plot to ./../../../resilience_code/data/plots/sigmod_figures/expt-tpch-resp-5Chain.pdf

# %%
EXPT_DATA_FILE = './../../../resilience_code/data/tpch_expt/expt-resp-case-{}.csv'
PLOT_OUTPUT_FILE = './../../../resilience_code/data/plots/sigmod_figures/expt-tpch-resp-5Cycle.pdf'

expt_type = 'Responsibility'
BUCKET_SIZE_DENOMINATOR = 3
DATA_ALPHA = 0.7
g00_ymax = 1e4
g00_ymin = 1e-2
g01_ymax = 1e4*1.2
g11_ymax = 1e1
xmax = 1e5
xmin = 1
plot_legend = True
g00_arrow_point = 13
plot.synthetic_expt_plotter.plot_resilience_expt(2, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, BUCKET_SIZE_DENOMINATOR = BUCKET_SIZE_DENOMINATOR, expt_type= expt_type, DATA_ALPHA = DATA_ALPHA, 
                        g00_ymax = g00_ymax, g11_ymax = g11_ymax, xmax=xmax, hide_bottom_plots = hide_bottom_plots, g01_ymax=g01_ymax, plot_legend = plot_legend, g00_ymin = g00_ymin, g00_arrow_point = g00_arrow_point, xmin = xmin)
# Out:
# Saving plot to ./../../../resilience_code/data/plots/sigmod_figures/expt-tpch-resp-5Cycle.pdf

# %% [markdown]
# ## Self - Join Bag Experiments Resilience

# %%
EXPT_DATA_FILE = './../../../resilience_code/data/synthetic_expt/expt-data-case-{}.csv'
PLOT_OUTPUT_FILE = None # To show output in notebook

# %%
g00_ymax = 1e4
g00_ymax = 6000
DATA_ALPHA = 0.1
PLOT_OUTPUT_FILE = './../../../resilience_code/data/plots/sigmod_figures/expt-sj-chain-bags.pdf'
DATA_ALPHA = 0.7
g00_ymin = 1e-2
plot.synthetic_expt_plotter.plot_resilience_expt(137, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, hide_bottom_plots = hide_bottom_plots, DATA_ALPHA = DATA_ALPHA, g00_ymax = g00_ymax, g00_ymin = g00_ymin, g01_ymax = g01_ymax)
# Out:
# Saving plot to ./../../../resilience_code/data/plots/sigmod_figures/expt-sj-chain-bags.pdf

# %%
PLOT_OUTPUT_FILE = './../../../resilience_code/data/plots/sigmod_figures/expt-sj-conf-bags.pdf'
g00_ymax = 1e1
g01_ymax = 1e3
plot_legend = True
DATA_ALPHA = 0.7
g00_ymin = 1e-2
plot.synthetic_expt_plotter.plot_resilience_expt(138, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, hide_bottom_plots = hide_bottom_plots, g00_ymax = g00_ymax, g00_ymin = g00_ymin, g01_ymax = g01_ymax, plot_legend=plot_legend, DATA_ALPHA=DATA_ALPHA)
# Out:
# Saving plot to ./../../../resilience_code/data/plots/sigmod_figures/expt-sj-conf-bags.pdf

# %% [markdown]
# ## A case that is easy for sets and hard for bags

# %%
xmax = 1e6
g11_ymax = 2
g00_ymax = 1e2+50
g01_ymax = 1e3
plot_legend = True
DATA_ALPHA = 0.7
g00_ymin = 1e-2
g00_arrow_point = 21
PLOT_OUTPUT_FILE = './../../../resilience_code/data/plots/sigmod_figures/expt-tu-bags.pdf'
plot.synthetic_expt_plotter.plot_resilience_expt(133, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, xmax=xmax, g11_ymax = g11_ymax, hide_bottom_plots = hide_bottom_plots,  g00_ymin = g00_ymin, g00_ymax = g00_ymax, g01_ymax = g01_ymax, plot_legend=plot_legend, DATA_ALPHA=DATA_ALPHA, g00_arrow_point=g00_arrow_point)
# Out:
# Saving plot to ./../../../resilience_code/data/plots/sigmod_figures/expt-tu-bags.pdf

# %%
EXPT_DATA_FILE = './../../../resilience_code/data/synthetic_expt/expt-data-case-{}.csv'
xmax = 1e6
g11_ymax = 1e2
DATA_ALPHA = 0.7
g00_ymax = 1e2
g01_ymax = 1e2+ 20
g00_arrow_point = 21
g00_ymin= 1e-2
PLOT_OUTPUT_FILE = './../../../resilience_code/data/plots/sigmod_figures/expt-tu-sets.pdf'
plot.synthetic_expt_plotter.plot_resilience_expt(33, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, xmax=1e6, g11_ymax = g11_ymax, DATA_ALPHA=DATA_ALPHA , g00_ymin = g00_ymin, hide_bottom_plots = hide_bottom_plots, g00_ymax = g00_ymax, g01_ymax = g01_ymax, g00_arrow_point=g00_arrow_point)
# Out:
# Saving plot to ./../../../resilience_code/data/plots/sigmod_figures/expt-tu-sets.pdf

# %%
EXPT_DATA_FILE = './../../../resilience_code/data/synthetic_expt/expt-data-case-{}.csv'
xmax = 1e6
g00_ymax = 1e2
g01_ymax = 1e2
PLOT_OUTPUT_FILE = None
DATA_ALPHA=0.7
plot.synthetic_expt_plotter.plot_resilience_expt(43, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, xmax=xmax,hide_bottom_plots = hide_bottom_plots,  g00_ymax = g00_ymax, g01_ymax = g01_ymax, DATA_ALPHA=DATA_ALPHA)

# %%
# SJ conf under Set Semantics

EXPT_DATA_FILE = './../../../resilience_code/data/synthetic_expt/expt-data-case-{}.csv'
xmax = 1e5 *5
g00_ymax = 1e2
g01_ymax = 1e2
DATA_ALPHA = 0.7
PLOT_OUTPUT_FILE = './../../../resilience_code/data/plots/sigmod_figures/expt-sj-z6.pdf'
plot.synthetic_expt_plotter.plot_resilience_expt(44, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, xmax=xmax, g11_ymax = 1e2, g10_ymax = 1e2, hide_bottom_plots = hide_bottom_plots, DATA_ALPHA=DATA_ALPHA, g00_ymax = g00_ymax, g01_ymax = g01_ymax)
# Out:
# Saving plot to ./../../../resilience_code/data/plots/sigmod_figures/expt-sj-z6.pdf

# %%
# 3Star Query with Delta Plots

EXPT_DATA_FILE = './../../../resilience_code/data/synthetic_expt/expt-data-case-{}.csv'
xmax = 1e3*2
g00_ymax = 1e5
g01_ymax = 1000
g10_ymax = 1e4*7
g11_ymax = 2
g11_ymin = 0.9
g00_arrow_point = 1
g11_arrow_points = []
g00_arrow_point = 32
g11_arrow_points = [(27,'ilp_results', 'flow_tuple_linearization_lp_results'),
                    (23,'ilp_results', 'flow_witness_linearization_lp_results'),
                    (32,'ilp_results', 'lp_results: approximation')]
DATA_ALPHA = 0.7
PLOT_OUTPUT_FILE = './../../../resilience_code/data/plots/sigmod_figures/expt-3star-with-deltas-domain-500.pdf'
plot.synthetic_expt_plotter.plot_resilience_expt_with_deltas(81, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, BUCKET_SIZE_DENOMINATOR = 10, g00_ymax=g00_ymax, g01_ymax=g01_ymax, g11_ymax = g11_ymax, g10_ymax= g10_ymax, g11_ymin= g11_ymin, DATA_ALPHA=DATA_ALPHA, xmax = xmax, g00_arrow_point = g00_arrow_point, g11_arrow_points = g11_arrow_points)
# Out:
# Saving plot to ./../../../resilience_code/data/plots/sigmod_figures/expt-3star-with-deltas-domain-500.pdf
