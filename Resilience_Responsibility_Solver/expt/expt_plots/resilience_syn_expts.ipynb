# %% [markdown]
# ## Synthetic Experiments on Resilience

# %%
# Import required methods
import sys
sys.path.append('./../../../resilience_code/')

import plot.synthetic_expt_plotter

# %%
EXPT_DATA_FILE = './../../../resilience_code/data/synthetic_expt/expt-data-case-{}.csv'
PLOT_OUTPUT_FILE = None # To show output in notebook

# %%
BUCKET_SIZE_DENOMINATOR = 8 # (4 implies that buckets are of size 10^(1/4))
DATA_ALPHA = 0.1 # alpha value of all points that are not bucket medians

# %%
BUCKET_SIZE_DENOMINATOR = 16
g01_ymax = 1e3
g11_ymax = 5
plot.synthetic_expt_plotter.plot_resilience_expt(31, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, BUCKET_SIZE_DENOMINATOR = BUCKET_SIZE_DENOMINATOR, DATA_ALPHA = DATA_ALPHA, g01_ymax = g01_ymax, g11_ymax = g11_ymax)

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(32, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(33, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(34, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(35, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(36, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(37, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(38, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(40, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(41, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(42, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)
