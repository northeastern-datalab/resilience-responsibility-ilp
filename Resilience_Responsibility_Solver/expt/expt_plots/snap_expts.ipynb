# %% [markdown]
# ## Snap experiments

# %%
# Import required methods
import sys
sys.path.append('./../../../resilience_code/')

import plot.synthetic_expt_plotter

# %%
EXPT_DATA_FILE = './../../../resilience_code/data/snap/expt-data-case-{}.csv'
PLOT_OUTPUT_FILE = None # To show output in notebook

# %%
BUCKET_SIZE_DENOMINATOR = 1
DATA_ALPHA = 0.1
g11_ymax = 1e1
xmax = 1e4
plot.synthetic_expt_plotter.plot_resilience_expt(1, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, BUCKET_SIZE_DENOMINATOR = BUCKET_SIZE_DENOMINATOR, DATA_ALPHA = DATA_ALPHA, g11_ymax = g11_ymax, xmax=xmax)

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(2, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)

# %% [markdown]
# ## Part 2: Responsibility

# %%
EXPT_DATA_FILE = './../../../resilience_code/data/snap/resp-expt-data-case-{}.csv'
expt_type = 'Responsibility'
PLOT_OUTPUT_FILE = None # To show output in notebook

# %%
BUCKET_SIZE_DENOMINATOR = 1
DATA_ALPHA = 0.1
g11_ymax = 10e5
xmax = 10e6
plot.synthetic_expt_plotter.plot_resilience_expt(1, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, BUCKET_SIZE_DENOMINATOR = BUCKET_SIZE_DENOMINATOR, expt_type= expt_type, DATA_ALPHA = DATA_ALPHA, g11_ymax = g11_ymax, xmax=xmax)

# %%
BUCKET_SIZE_DENOMINATOR = 4
DATA_ALPHA = 0.1
g11_ymax = 10e5
xmax = 1e4
plot.synthetic_expt_plotter.plot_resilience_expt(2, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, BUCKET_SIZE_DENOMINATOR = BUCKET_SIZE_DENOMINATOR, expt_type= expt_type, DATA_ALPHA = DATA_ALPHA, g11_ymax = g11_ymax, xmax=xmax)
