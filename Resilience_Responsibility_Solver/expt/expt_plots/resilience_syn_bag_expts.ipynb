# %% [markdown]
# ## Synthetic Experiments on Resilience

# %%
# Import required methods
import sys
sys.path.append('./../../../resilience_code/')

import plot.synthetic_expt_plotter

# %%
EXPT_DATA_FILE = './../../../resilience_code/data/synthetic_expt/expt-data-case-{}.csv'
PLOT_OUTPUT_FILE = None # To show output in notebook

# %%
BUCKET_SIZE_DENOMINATOR = 4 # (4 implies that buckets are of size 10^(1/4))
DATA_ALPHA = 0.1 # alpha value of all points that are not bucket medians

# %%
BUCKET_SIZE_DENOMINATOR = 6
g11_ymax = 5
plot.synthetic_expt_plotter.plot_resilience_expt(131, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, BUCKET_SIZE_DENOMINATOR = BUCKET_SIZE_DENOMINATOR, DATA_ALPHA = DATA_ALPHA, g11_ymax = g11_ymax)

# %%
g11_ymax = 1e1
plot.synthetic_expt_plotter.plot_resilience_expt(132, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)

# %%
xmax = 1e6
plot.synthetic_expt_plotter.plot_resilience_expt(133, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, xmax=xmax)

# %%
xmax = 1e6
plot.synthetic_expt_plotter.plot_resilience_expt(143, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, xmax=xmax)

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(134, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(135, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(136, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(137, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(138, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(140, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(141, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(142, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE)
