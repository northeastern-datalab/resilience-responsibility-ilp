# %% [markdown]
# ## Synthetic Experiments on Resilience

# %%
# Import required methods
import sys
sys.path.append('./../../../resilience_code/')

import plot.synthetic_expt_plotter

# %%
EXPT_DATA_FILE = './../../../resilience_code/data/resp_synthetic_expt/expt-data-case-{}.csv'
PLOT_OUTPUT_FILE = None # To show output in notebook
expt_type = "Responsibility"

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(31, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(32, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(33, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(34, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(35, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(36, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(37, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(38, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(39, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(40, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(41, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(42, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(43, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(44, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")
