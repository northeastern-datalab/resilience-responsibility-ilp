# %% [markdown]
# ## Synthetic Experiments on Resilience

# %%
# Import required methods
import sys
sys.path.append('./../../../resilience_code/')

import plot.synthetic_expt_plotter

# %%
EXPT_DATA_FILE = './../../../resilience_code/data/resp_synthetic_expt/expt-data-case-{}.csv'
PLOT_OUTPUT_FILE = None # To show output in notebook
expt_type = "Responsibility"

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(131, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(132, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(133, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(134, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(135, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(136, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(137, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# c:\neha\research\resilience\resilience_code\expt\expt_plots\responsibility_syn_bag_expts.ipynb Cell 10 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/neha/research/resilience/resilience_code/expt/expt_plots/responsibility_syn_bag_expts.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> plot.synthetic_expt_plotter.plot_resilience_expt(137, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")
#
# File c:\neha\research\resilience\resilience_code\expt\expt_plots\./../../../resilience_code\plot\synthetic_expt_plotter.py:92, in plot_resilience_expt(case_no, EXPT_DATA_FILE, PLOT_OUTPUT_FILE, expt_type, BUCKET_SIZE_DENOMINATOR, DATA_ALPHA, xmax, g00_ymax, g01_ymax, g10_ymax, g11_ymax)
#      82 """
#      83 Generate and save a plot from the data available for a synthetic expt case
#      84
# ...

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(138, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(139, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(140, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(141, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(142, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(143, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")

# %%
plot.synthetic_expt_plotter.plot_resilience_expt(144, EXPT_DATA_FILE = EXPT_DATA_FILE, PLOT_OUTPUT_FILE = PLOT_OUTPUT_FILE, expt_type="Responsibility")
